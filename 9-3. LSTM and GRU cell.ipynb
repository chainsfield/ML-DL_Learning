# %% [markdown]
# # LSTM과 GRU 셀

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/9-3.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## LSTM 신경망 훈련하기

# %%
from tensorflow.keras.datasets import imdb
# 데이터 세트 imdb import
from sklearn.model_selection import train_test_split
# train_test_split import

(train_input, train_target), (test_input, test_target) = imdb.load_data(num_words=500)
# num_words=500으로 데이터셋에서 가장 자주 등장하는 단어 500개만 사용

train_input, val_input, train_target, val_target = train_test_split(train_input, train_target, test_size=0.2, random_state=42)
# 훈련 세트와 검증 세트를 8:2 비율로 나눔
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# pad_sequences import
train_seq = pad_sequences(train_input, maxlen=100)
# max_len=100으로 설정하여 train_input의 길이를 100으로 맞춤
val_seq = pad_sequences(val_input, maxlen=100)
# max_len=100으로 설정하여 val_input의 길이를 100으로 맞춤

# %%
from tensorflow import keras
# keras import
model = keras.Sequential()
# Sequential 객체 model 생성
model.add(keras.layers.Embedding(500, 16, input_length=100))
# model에 Embedding 층 추가, 단어 사전의 크기는 500, 임베딩 벡터의 크기는 16, input_length=100으로 설정
model.add(keras.layers.LSTM(8))
# model에 LSTM 층 추가
model.add(keras.layers.Dense(1, activation='sigmoid'))
# model에 출력 층 추가, 이진 분류이기 때문에 1개의 뉴런과 시그모이드 활성화 함수를 사용
model.summary()
# model 요약 내용 출력
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           8000
#
#  lstm (LSTM)                 (None, 8)                 800
#
#  dense (Dense)               (None, 1)                 9
#
# =================================================================
# Total params: 8809 (34.41 KB)
# Trainable params: 8809 (34.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# RMSprop의 학습률을 0.0001로 지정

model.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])
# optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy']으로 설정

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-lstm-model.h5')
# ModelCheckpoint 콜백 사용

early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# EarlyStopping 콜백 사용, patience=3으로 설정

history = model.fit(train_seq, train_target, epochs=100, batch_size=64, validation_data=(val_seq, val_target), callbacks=[checkpoint_cb, early_stopping_cb])
# epoch=100, batch_size=64로 설정하고 훈련
# Out:
# Epoch 1/100
# 313/313 [==============================] - 14s 20ms/step - loss: 0.6929 - accuracy: 0.5129 - val_loss: 0.6921 - val_accuracy: 0.5416
# Epoch 2/100
#   9/313 [..............................] - ETA: 1s - loss: 0.6920 - accuracy: 0.5434
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6912 - accuracy: 0.5659 - val_loss: 0.6901 - val_accuracy: 0.6002
# Epoch 3/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6884 - accuracy: 0.6091 - val_loss: 0.6865 - val_accuracy: 0.6234
# Epoch 4/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6830 - accuracy: 0.6328 - val_loss: 0.6791 - val_accuracy: 0.6440
# Epoch 5/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6698 - accuracy: 0.6607 - val_loss: 0.6574 - val_accuracy: 0.6790
# Epoch 6/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6173 - accuracy: 0.7084 - val_loss: 0.5864 - val_accuracy: 0.7098
# Epoch 7/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.5707 - accuracy: 0.7269 - val_loss: 0.5627 - val_accuracy: 0.7324
# Epoch 8/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5475 - accuracy: 0.7451 - val_loss: 0.5426 - val_accuracy: 0.7470
# Epoch 9/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5276 - accuracy: 0.7581 - val_loss: 0.5260 - val_accuracy: 0.7552
# Epoch 10/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5099 - accuracy: 0.7687 - val_loss: 0.5087 - val_accuracy: 0.7696
# Epoch 11/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4943 - accuracy: 0.7793 - val_loss: 0.4961 - val_accuracy: 0.7760
# Epoch 12/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4807 - accuracy: 0.7866 - val_loss: 0.4841 - val_accuracy: 0.7822
# Epoch 13/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4685 - accuracy: 0.7916 - val_loss: 0.4787 - val_accuracy: 0.7784
# Epoch 14/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4590 - accuracy: 0.7987 - val_loss: 0.4680 - val_accuracy: 0.7840
# Epoch 15/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4508 - accuracy: 0.8001 - val_loss: 0.4606 - val_accuracy: 0.7862
# Epoch 16/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4437 - accuracy: 0.8048 - val_loss: 0.4546 - val_accuracy: 0.7914
# Epoch 17/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4381 - accuracy: 0.8064 - val_loss: 0.4510 - val_accuracy: 0.7946
# Epoch 18/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4335 - accuracy: 0.8098 - val_loss: 0.4472 - val_accuracy: 0.7940
# Epoch 19/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4298 - accuracy: 0.8105 - val_loss: 0.4446 - val_accuracy: 0.7958
# Epoch 20/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4262 - accuracy: 0.8111 - val_loss: 0.4465 - val_accuracy: 0.7912
# Epoch 21/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4238 - accuracy: 0.8126 - val_loss: 0.4474 - val_accuracy: 0.7894
# Epoch 22/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4217 - accuracy: 0.8134 - val_loss: 0.4402 - val_accuracy: 0.7962
# Epoch 23/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4194 - accuracy: 0.8135 - val_loss: 0.4407 - val_accuracy: 0.7954
# Epoch 24/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4177 - accuracy: 0.8158 - val_loss: 0.4391 - val_accuracy: 0.7964
# Epoch 25/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4160 - accuracy: 0.8139 - val_loss: 0.4362 - val_accuracy: 0.7988
# Epoch 26/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4145 - accuracy: 0.8152 - val_loss: 0.4384 - val_accuracy: 0.8004
# Epoch 27/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4130 - accuracy: 0.8159 - val_loss: 0.4440 - val_accuracy: 0.7888
# Epoch 28/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4121 - accuracy: 0.8157 - val_loss: 0.4335 - val_accuracy: 0.7994
# Epoch 29/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4108 - accuracy: 0.8163 - val_loss: 0.4335 - val_accuracy: 0.7990
# Epoch 30/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4096 - accuracy: 0.8175 - val_loss: 0.4316 - val_accuracy: 0.8010
# Epoch 31/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4086 - accuracy: 0.8166 - val_loss: 0.4316 - val_accuracy: 0.7990
# Epoch 32/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4075 - accuracy: 0.8172 - val_loss: 0.4323 - val_accuracy: 0.8048
# Epoch 33/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4067 - accuracy: 0.8181 - val_loss: 0.4305 - val_accuracy: 0.8046
# Epoch 34/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4059 - accuracy: 0.8169 - val_loss: 0.4297 - val_accuracy: 0.8008
# Epoch 35/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4050 - accuracy: 0.8190 - val_loss: 0.4298 - val_accuracy: 0.8052
# Epoch 36/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4039 - accuracy: 0.8191 - val_loss: 0.4299 - val_accuracy: 0.7984
# Epoch 37/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4033 - accuracy: 0.8189 - val_loss: 0.4295 - val_accuracy: 0.8064
# Epoch 38/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4026 - accuracy: 0.8192 - val_loss: 0.4289 - val_accuracy: 0.7992
# Epoch 39/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4019 - accuracy: 0.8183 - val_loss: 0.4287 - val_accuracy: 0.8004
# Epoch 40/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4010 - accuracy: 0.8203 - val_loss: 0.4446 - val_accuracy: 0.7958
# Epoch 41/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4005 - accuracy: 0.8190 - val_loss: 0.4288 - val_accuracy: 0.8066
# Epoch 42/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.3998 - accuracy: 0.8216 - val_loss: 0.4267 - val_accuracy: 0.8072
# Epoch 43/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3990 - accuracy: 0.8202 - val_loss: 0.4292 - val_accuracy: 0.7986
# Epoch 44/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3980 - accuracy: 0.8216 - val_loss: 0.4260 - val_accuracy: 0.8044
# Epoch 45/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3977 - accuracy: 0.8216 - val_loss: 0.4259 - val_accuracy: 0.8052
# Epoch 46/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3970 - accuracy: 0.8217 - val_loss: 0.4256 - val_accuracy: 0.8082
# Epoch 47/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3965 - accuracy: 0.8217 - val_loss: 0.4269 - val_accuracy: 0.8070
# Epoch 48/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3954 - accuracy: 0.8213 - val_loss: 0.4250 - val_accuracy: 0.8082
# Epoch 49/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3951 - accuracy: 0.8218 - val_loss: 0.4259 - val_accuracy: 0.8020
# Epoch 50/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3943 - accuracy: 0.8233 - val_loss: 0.4246 - val_accuracy: 0.8054
# Epoch 51/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3933 - accuracy: 0.8232 - val_loss: 0.4245 - val_accuracy: 0.8074
# Epoch 52/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3928 - accuracy: 0.8210 - val_loss: 0.4247 - val_accuracy: 0.8068
# Epoch 53/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3920 - accuracy: 0.8236 - val_loss: 0.4238 - val_accuracy: 0.8058
# Epoch 54/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3915 - accuracy: 0.8241 - val_loss: 0.4281 - val_accuracy: 0.8024
# Epoch 55/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3910 - accuracy: 0.8249 - val_loss: 0.4269 - val_accuracy: 0.8048
# Epoch 56/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3903 - accuracy: 0.8234 - val_loss: 0.4235 - val_accuracy: 0.8080
# Epoch 57/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3897 - accuracy: 0.8233 - val_loss: 0.4255 - val_accuracy: 0.8050
# Epoch 58/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3891 - accuracy: 0.8252 - val_loss: 0.4253 - val_accuracy: 0.8044
# Epoch 59/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3886 - accuracy: 0.8255 - val_loss: 0.4238 - val_accuracy: 0.8082

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# 훈련 세트와 검증 세트 손실 그래프 출력

# %% [markdown]
# ## 순환 층에 드롭아웃 적용하기

# %%
model2 = keras.Sequential()
# Sequential 클래스 객체 model2 생성
model2.add(keras.layers.Embedding(500, 16, input_length=100))
# model2에 Embedding층 추가, 단어 사전의 크기는 500, 임베딩 벡터의 크기는 16, input_length=100으로 설정
model2.add(keras.layers.LSTM(8, dropout=0.3))
# mdoel2에 LSTM 층 추가, dropout=0.3으로 설정해서 30%의 입력을 드롭아웃
model2.add(keras.layers.Dense(1, activation='sigmoid'))
# model2에 출력층 추가, 이진 분류이기 때문에 1개의 뉴런과 시그모이드 활성화 함수를 사용

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# RMSprop의 학습률을 0.0001로 지정

model2.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])
# optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy']으로 설정

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-dropout-model.h5')
# ModelCheckpoint 콜백 사용

early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# EarlyStopping 콜백 사용, patience=3으로 설정

history = model2.fit(train_seq, train_target, epochs=100, batch_size=64, validation_data=(val_seq, val_target), callbacks=[checkpoint_cb, early_stopping_cb])
# epoch=100, batch_size=64로 설정하고 훈련
# Out:
# Epoch 1/100
# 313/313 [==============================] - 8s 16ms/step - loss: 0.6930 - accuracy: 0.5046 - val_loss: 0.6923 - val_accuracy: 0.5430
# Epoch 2/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.6910 - accuracy: 0.5691 - val_loss: 0.6897 - val_accuracy: 0.6102
# Epoch 3/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6859 - accuracy: 0.6262 - val_loss: 0.6792 - val_accuracy: 0.6634
# Epoch 4/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6590 - accuracy: 0.6683 - val_loss: 0.6355 - val_accuracy: 0.6832
# Epoch 5/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6213 - accuracy: 0.6916 - val_loss: 0.6055 - val_accuracy: 0.7114
# Epoch 6/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5956 - accuracy: 0.7132 - val_loss: 0.5802 - val_accuracy: 0.7300
# Epoch 7/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.5710 - accuracy: 0.7342 - val_loss: 0.5607 - val_accuracy: 0.7352
# Epoch 8/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5484 - accuracy: 0.7469 - val_loss: 0.5347 - val_accuracy: 0.7580
# Epoch 9/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5263 - accuracy: 0.7599 - val_loss: 0.5140 - val_accuracy: 0.7730
# Epoch 10/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5046 - accuracy: 0.7726 - val_loss: 0.4957 - val_accuracy: 0.7778
# Epoch 11/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4884 - accuracy: 0.7801 - val_loss: 0.4817 - val_accuracy: 0.7862
# Epoch 12/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4753 - accuracy: 0.7885 - val_loss: 0.4728 - val_accuracy: 0.7896
# Epoch 13/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4688 - accuracy: 0.7879 - val_loss: 0.4683 - val_accuracy: 0.7830
# Epoch 14/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4618 - accuracy: 0.7892 - val_loss: 0.4606 - val_accuracy: 0.7924
# Epoch 15/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4544 - accuracy: 0.7938 - val_loss: 0.4557 - val_accuracy: 0.7934
# Epoch 16/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4502 - accuracy: 0.7952 - val_loss: 0.4522 - val_accuracy: 0.7944
# Epoch 17/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4452 - accuracy: 0.7982 - val_loss: 0.4514 - val_accuracy: 0.7946
# Epoch 18/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4414 - accuracy: 0.8004 - val_loss: 0.4472 - val_accuracy: 0.7956
# Epoch 19/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4388 - accuracy: 0.8025 - val_loss: 0.4458 - val_accuracy: 0.7930
# Epoch 20/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4357 - accuracy: 0.8018 - val_loss: 0.4427 - val_accuracy: 0.7968
# Epoch 21/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4337 - accuracy: 0.8040 - val_loss: 0.4410 - val_accuracy: 0.7966
# Epoch 22/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4314 - accuracy: 0.8033 - val_loss: 0.4401 - val_accuracy: 0.7988
# Epoch 23/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4286 - accuracy: 0.8064 - val_loss: 0.4385 - val_accuracy: 0.7992
# Epoch 24/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4274 - accuracy: 0.8069 - val_loss: 0.4371 - val_accuracy: 0.8008
# Epoch 25/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4259 - accuracy: 0.8063 - val_loss: 0.4352 - val_accuracy: 0.7994
# Epoch 26/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4253 - accuracy: 0.8074 - val_loss: 0.4375 - val_accuracy: 0.8020
# Epoch 27/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4232 - accuracy: 0.8070 - val_loss: 0.4332 - val_accuracy: 0.8000
# Epoch 28/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4204 - accuracy: 0.8097 - val_loss: 0.4349 - val_accuracy: 0.8028
# Epoch 29/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4203 - accuracy: 0.8101 - val_loss: 0.4418 - val_accuracy: 0.8018
# Epoch 30/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4188 - accuracy: 0.8108 - val_loss: 0.4348 - val_accuracy: 0.7958

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# 훈련 세트와 검증 세트 손실 그래프 출력

# %% [markdown]
# ## 2개의 층을 연결하기

# %%
model3 = keras.Sequential()
# Sequential 클래스 객체 model3 생성
model3.add(keras.layers.Embedding(500, 16, input_length=100))
# model3에 Embedding 층 추가, 단어 사전의 크기는 500, 임베딩 벡터의 크기는 16, input_length=100으로 설정
model3.add(keras.layers.LSTM(8, dropout=0.3, return_sequences=True))
# model3에 LSTM 층 추가, dropout=0.3으로 설정해서 30%의 입력을 드롭아웃, return_sequences=True로 해서 모든 타임스텝의 은닉 상태를 출력
model3.add(keras.layers.LSTM(8, dropout=0.3))
# model3에 LSTM 층 추가, dropout=0.3으로 설정해서 30%의 입력을 드롭아웃
model3.add(keras.layers.Dense(1, activation='sigmoid'))
# model3에 출력 층 추가, 이진 분류이기 때문에 1개의 뉴런과 시그모이드 활성화 함수를 사용
model3.summary()
# model3 요약 내용 출력
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 16)           8000
#
#  lstm_2 (LSTM)               (None, 100, 8)            800
#
#  lstm_3 (LSTM)               (None, 8)                 544
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 9353 (36.54 KB)
# Trainable params: 9353 (36.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# RMSprop의 학습률을 0.0001로 지정

model3.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])
# optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy']으로 설정

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-2rnn-model.h5')
# ModelCheckpoint 콜백 사용

early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# EarlyStopping 콜백 사용, patience=3으로 설정

history = model3.fit(train_seq, train_target, epochs=100, batch_size=64, validation_data=(val_seq, val_target), callbacks=[checkpoint_cb, early_stopping_cb])
# epoch=100, batch_size=64로 설정하고 훈련
# Out:
# Epoch 1/100
# 313/313 [==============================] - 11s 23ms/step - loss: 0.6929 - accuracy: 0.5124 - val_loss: 0.6926 - val_accuracy: 0.5174
# Epoch 2/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6911 - accuracy: 0.5667 - val_loss: 0.6884 - val_accuracy: 0.6398
# Epoch 3/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.6783 - accuracy: 0.6443 - val_loss: 0.6583 - val_accuracy: 0.6760
# Epoch 4/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6198 - accuracy: 0.6901 - val_loss: 0.5862 - val_accuracy: 0.7080
# Epoch 5/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.5677 - accuracy: 0.7214 - val_loss: 0.5507 - val_accuracy: 0.7338
# Epoch 6/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5407 - accuracy: 0.7424 - val_loss: 0.5271 - val_accuracy: 0.7492
# Epoch 7/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.5205 - accuracy: 0.7551 - val_loss: 0.5147 - val_accuracy: 0.7576
# Epoch 8/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.5053 - accuracy: 0.7627 - val_loss: 0.4937 - val_accuracy: 0.7760
# Epoch 9/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4946 - accuracy: 0.7727 - val_loss: 0.4838 - val_accuracy: 0.7804
# Epoch 10/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4822 - accuracy: 0.7793 - val_loss: 0.4760 - val_accuracy: 0.7830
# Epoch 11/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4786 - accuracy: 0.7803 - val_loss: 0.4748 - val_accuracy: 0.7792
# Epoch 12/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4703 - accuracy: 0.7840 - val_loss: 0.4671 - val_accuracy: 0.7842
# Epoch 13/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.4653 - accuracy: 0.7867 - val_loss: 0.4616 - val_accuracy: 0.7890
# Epoch 14/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4616 - accuracy: 0.7885 - val_loss: 0.4583 - val_accuracy: 0.7902
# Epoch 15/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4536 - accuracy: 0.7924 - val_loss: 0.4534 - val_accuracy: 0.7930
# Epoch 16/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4519 - accuracy: 0.7957 - val_loss: 0.4551 - val_accuracy: 0.7882
# Epoch 17/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4499 - accuracy: 0.7950 - val_loss: 0.4494 - val_accuracy: 0.7946
# Epoch 18/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4468 - accuracy: 0.7966 - val_loss: 0.4549 - val_accuracy: 0.7904
# Epoch 19/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4436 - accuracy: 0.7983 - val_loss: 0.4486 - val_accuracy: 0.7938
# Epoch 20/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.4408 - accuracy: 0.7988 - val_loss: 0.4473 - val_accuracy: 0.7948
# Epoch 21/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4404 - accuracy: 0.7987 - val_loss: 0.4448 - val_accuracy: 0.7950
# Epoch 22/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4379 - accuracy: 0.8022 - val_loss: 0.4435 - val_accuracy: 0.7948
# Epoch 23/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4384 - accuracy: 0.8001 - val_loss: 0.4455 - val_accuracy: 0.7906
# Epoch 24/100
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4351 - accuracy: 0.8013 - val_loss: 0.4492 - val_accuracy: 0.7960
# Epoch 25/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4355 - accuracy: 0.8012 - val_loss: 0.4511 - val_accuracy: 0.7838

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# 훈련 세트와 검증 세트 손실 그래프 출력

# %% [markdown]
# ## GRU 신경망 훈련하기

# %%
model4 = keras.Sequential()
# Sequential 클래스 객체 model4 생성
model4.add(keras.layers.Embedding(500, 16, input_length=100))
# model4에 Embedding층 추가, 단어 사전의 크기는 500, 임베딩 벡터의 크기는 16, input_length=100으로 설정
model4.add(keras.layers.GRU(8))
# mdoel4에 GRU 층 추가
model4.add(keras.layers.Dense(1, activation='sigmoid'))
# model4에 출력층 추가, 이진 분류이기 때문에 1개의 뉴런과 시그모이드 활성화 함수를 사용
model4.summary()
# model4 요약 내용 출력
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 16)           8000
#
#  gru (GRU)                   (None, 8)                 624
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8633 (33.72 KB)
# Trainable params: 8633 (33.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
# RMSprop의 학습률을 0.0001로 지정

model4.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy'])
# optimizer=rmsprop, loss='binary_crossentropy', metrics=['accuracy']으로 설정

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-gru-model.h5')
# ModelCheckpoint 콜백 사용

early_stopping_cb = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)
# EarlyStopping 콜백 사용, patience=3으로 설정

history = model4.fit(train_seq, train_target, epochs=100, batch_size=64, validation_data=(val_seq, val_target), callbacks=[checkpoint_cb, early_stopping_cb])
# epoch=100, batch_size=64로 설정하고 훈련
# Out:
# Epoch 1/100
# 313/313 [==============================] - 8s 19ms/step - loss: 0.6921 - accuracy: 0.5224 - val_loss: 0.6913 - val_accuracy: 0.5548
# Epoch 2/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6900 - accuracy: 0.5684 - val_loss: 0.6890 - val_accuracy: 0.5748
# Epoch 3/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6865 - accuracy: 0.5861 - val_loss: 0.6850 - val_accuracy: 0.5894
# Epoch 4/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6809 - accuracy: 0.6033 - val_loss: 0.6784 - val_accuracy: 0.6048
# Epoch 5/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6720 - accuracy: 0.6180 - val_loss: 0.6686 - val_accuracy: 0.6184
# Epoch 6/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.6582 - accuracy: 0.6355 - val_loss: 0.6525 - val_accuracy: 0.6372
# Epoch 7/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.6363 - accuracy: 0.6550 - val_loss: 0.6265 - val_accuracy: 0.6618
# Epoch 8/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5979 - accuracy: 0.6837 - val_loss: 0.5779 - val_accuracy: 0.7024
# Epoch 9/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5414 - accuracy: 0.7291 - val_loss: 0.5329 - val_accuracy: 0.7334
# Epoch 10/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.5136 - accuracy: 0.7513 - val_loss: 0.5144 - val_accuracy: 0.7482
# Epoch 11/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4966 - accuracy: 0.7623 - val_loss: 0.5001 - val_accuracy: 0.7588
# Epoch 12/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4830 - accuracy: 0.7703 - val_loss: 0.4871 - val_accuracy: 0.7722
# Epoch 13/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4711 - accuracy: 0.7791 - val_loss: 0.4770 - val_accuracy: 0.7730
# Epoch 14/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4620 - accuracy: 0.7831 - val_loss: 0.4695 - val_accuracy: 0.7802
# Epoch 15/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4551 - accuracy: 0.7883 - val_loss: 0.4632 - val_accuracy: 0.7814
# Epoch 16/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4483 - accuracy: 0.7916 - val_loss: 0.4593 - val_accuracy: 0.7850
# Epoch 17/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4436 - accuracy: 0.7947 - val_loss: 0.4539 - val_accuracy: 0.7860
# Epoch 18/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4388 - accuracy: 0.7987 - val_loss: 0.4519 - val_accuracy: 0.7842
# Epoch 19/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4347 - accuracy: 0.8012 - val_loss: 0.4491 - val_accuracy: 0.7888
# Epoch 20/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4319 - accuracy: 0.8037 - val_loss: 0.4475 - val_accuracy: 0.7902
# Epoch 21/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4285 - accuracy: 0.8055 - val_loss: 0.4457 - val_accuracy: 0.7890
# Epoch 22/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4266 - accuracy: 0.8064 - val_loss: 0.4549 - val_accuracy: 0.7930
# Epoch 23/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4247 - accuracy: 0.8069 - val_loss: 0.4434 - val_accuracy: 0.7930
# Epoch 24/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4230 - accuracy: 0.8091 - val_loss: 0.4423 - val_accuracy: 0.7942
# Epoch 25/100
# 313/313 [==============================] - 4s 11ms/step - loss: 0.4218 - accuracy: 0.8096 - val_loss: 0.4417 - val_accuracy: 0.7938
# Epoch 26/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4207 - accuracy: 0.8098 - val_loss: 0.4413 - val_accuracy: 0.7936
# Epoch 27/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4196 - accuracy: 0.8120 - val_loss: 0.4430 - val_accuracy: 0.7974
# Epoch 28/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4186 - accuracy: 0.8129 - val_loss: 0.4423 - val_accuracy: 0.7898
# Epoch 29/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4179 - accuracy: 0.8130 - val_loss: 0.4409 - val_accuracy: 0.7956
# Epoch 30/100
# 313/313 [==============================] - 3s 11ms/step - loss: 0.4171 - accuracy: 0.8135 - val_loss: 0.4409 - val_accuracy: 0.7966
# Epoch 31/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4165 - accuracy: 0.8134 - val_loss: 0.4407 - val_accuracy: 0.7988
# Epoch 32/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4159 - accuracy: 0.8148 - val_loss: 0.4411 - val_accuracy: 0.7948
# Epoch 33/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4154 - accuracy: 0.8145 - val_loss: 0.4427 - val_accuracy: 0.7978
# Epoch 34/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4152 - accuracy: 0.8157 - val_loss: 0.4433 - val_accuracy: 0.7902

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# 훈련 세트와 검증 세트 손실 그래프 출력

# %% [markdown]
# ## 마무리

# %%
test_seq = pad_sequences(test_input, maxlen=100)
# maxlen=100으로 설정하여 test_input의 길이를 100으로 맞춤
rnn_model = keras.models.load_model('best-2rnn-model.h5')
# 텐서플로 2.3에서는 버그(https://github.com/tensorflow/tensorflow/issues/42890) 때문에 compile() 메서드를 호출해야 합니다.
# rnn_model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics='accuracy')

rnn_model.evaluate(test_seq, test_target)
# 테스트 세트 성능 출력
# Out:
# 782/782 [==============================] - 6s 6ms/step - loss: 0.4484 - accuracy: 0.7886
# [0.4484458565711975, 0.788640022277832]
